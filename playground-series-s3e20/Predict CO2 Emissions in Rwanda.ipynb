# %%
import pandas as  pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-0.510_29.290_2019_00     -0.51      29.29  2019        0
# 1  ID_-0.510_29.290_2019_01     -0.51      29.29  2019        1
# 2  ID_-0.510_29.290_2019_02     -0.51      29.29  2019        2
# 3  ID_-0.510_29.290_2019_03     -0.51      29.29  2019        3
# 4  ID_-0.510_29.290_2019_04     -0.51      29.29  2019        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                 -0.000108
# 1                                  0.000021
# 2                                  0.000514
# 3                                       NaN
# 4                                 -0.000079
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                      0.603019
# 1                                      0.728214
# 2                                      0.748199
# 3                                           NaN
# 4                                      0.676296
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79023 entries, 0 to 79022
# Data columns (total 76 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   ID_LAT_LON_YEAR_WEEK                                      79023 non-null  object
#  1   latitude                                                  79023 non-null  float64
#  2   longitude                                                 79023 non-null  float64
#  3   year                                                      79023 non-null  int64
#  4   week_no                                                   79023 non-null  int64
#  5   SulphurDioxide_SO2_column_number_density                  64414 non-null  float64
#  6   SulphurDioxide_SO2_column_number_density_amf              64414 non-null  float64
#  7   SulphurDioxide_SO2_slant_column_number_density            64414 non-null  float64
# ...

# %%
a = []
i = 0
for each in df.isnull().sum():
    if each > 70000:
        a.append(i)
    i = i+1

# %%
df.drop([df.columns[i] for i in a],  axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79023 entries, 0 to 79022
# Data columns (total 69 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   ID_LAT_LON_YEAR_WEEK                                      79023 non-null  object
#  1   latitude                                                  79023 non-null  float64
#  2   longitude                                                 79023 non-null  float64
#  3   year                                                      79023 non-null  int64
#  4   week_no                                                   79023 non-null  int64
#  5   SulphurDioxide_SO2_column_number_density                  64414 non-null  float64
#  6   SulphurDioxide_SO2_column_number_density_amf              64414 non-null  float64
#  7   SulphurDioxide_SO2_slant_column_number_density            64414 non-null  float64
# ...

# %%
df.drop('ID_LAT_LON_YEAR_WEEK', 1, inplace=True)

# %%
df
# Out:
#        latitude  longitude  year  week_no  \
# 0        -0.510     29.290  2019        0
# 1        -0.510     29.290  2019        1
# 2        -0.510     29.290  2019        2
# 3        -0.510     29.290  2019        3
# 4        -0.510     29.290  2019        4
# ...         ...        ...   ...      ...
# 79018    -3.299     30.301  2021       48
# 79019    -3.299     30.301  2021       49
# 79020    -3.299     30.301  2021       50
# 79021    -3.299     30.301  2021       51
# 79022    -3.299     30.301  2021       52
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                     -0.000108
# 1                                      0.000021
# 2                                      0.000514
# 3                                           NaN
# 4                                     -0.000079
# ...                                         ...
# 79018                                  0.000284
# 79019                                  0.000083
# ...

# %% [markdown]
# ### GroupBy Function
# Let's do something with groupby function.
# - Groupby by:
#
#       - year
#       - latitude
#       - longitude
#       - week no
#   Here, emission is plotted with respect to these colums to know what is the distribution of C02 emission across these columns.

# %%
df.groupby(df['year']).max()['emission'].plot(kind='bar');

# %%
df.groupby(df['year']).mean()['emission'].plot(kind='bar');

# %%
df.groupby(df['latitude']).mean()['emission'].plot(kind='line');

# %%
df.groupby(df['longitude']).mean()['emission'].plot(kind='line');

# %%
df.groupby(df['week_no']).mean()['emission'].plot(kind='line');

# %%
df.dropna()
# Out:
#        latitude  longitude  year  week_no  \
# 1        -0.510     29.290  2019        1
# 2        -0.510     29.290  2019        2
# 4        -0.510     29.290  2019        4
# 5        -0.510     29.290  2019        5
# 6        -0.510     29.290  2019        6
# ...         ...        ...   ...      ...
# 79017    -3.299     30.301  2021       47
# 79018    -3.299     30.301  2021       48
# 79019    -3.299     30.301  2021       49
# 79021    -3.299     30.301  2021       51
# 79022    -3.299     30.301  2021       52
#
#        SulphurDioxide_SO2_column_number_density  \
# 1                                      0.000021
# 2                                      0.000514
# 4                                     -0.000079
# 5                                      0.000294
# 6                                     -0.000285
# ...                                         ...
# 79017                                 -0.000257
# 79018                                  0.000284
# ...
