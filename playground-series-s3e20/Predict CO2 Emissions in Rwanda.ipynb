# %%
import pandas as  pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-0.510_29.290_2019_00     -0.51      29.29  2019        0
# 1  ID_-0.510_29.290_2019_01     -0.51      29.29  2019        1
# 2  ID_-0.510_29.290_2019_02     -0.51      29.29  2019        2
# 3  ID_-0.510_29.290_2019_03     -0.51      29.29  2019        3
# 4  ID_-0.510_29.290_2019_04     -0.51      29.29  2019        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                 -0.000108
# 1                                  0.000021
# 2                                  0.000514
# 3                                       NaN
# 4                                 -0.000079
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                      0.603019
# 1                                      0.728214
# 2                                      0.748199
# 3                                           NaN
# 4                                      0.676296
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79023 entries, 0 to 79022
# Data columns (total 76 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   ID_LAT_LON_YEAR_WEEK                                      79023 non-null  object
#  1   latitude                                                  79023 non-null  float64
#  2   longitude                                                 79023 non-null  float64
#  3   year                                                      79023 non-null  int64
#  4   week_no                                                   79023 non-null  int64
#  5   SulphurDioxide_SO2_column_number_density                  64414 non-null  float64
#  6   SulphurDioxide_SO2_column_number_density_amf              64414 non-null  float64
#  7   SulphurDioxide_SO2_slant_column_number_density            64414 non-null  float64
# ...

# %%
a = []
i = 0
for each in df.isnull().sum():
    if each > 70000:
        a.append(i)
    i = i+1

# %%
df.drop([df.columns[i] for i in a],  axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79023 entries, 0 to 79022
# Data columns (total 69 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   ID_LAT_LON_YEAR_WEEK                                      79023 non-null  object
#  1   latitude                                                  79023 non-null  float64
#  2   longitude                                                 79023 non-null  float64
#  3   year                                                      79023 non-null  int64
#  4   week_no                                                   79023 non-null  int64
#  5   SulphurDioxide_SO2_column_number_density                  64414 non-null  float64
#  6   SulphurDioxide_SO2_column_number_density_amf              64414 non-null  float64
#  7   SulphurDioxide_SO2_slant_column_number_density            64414 non-null  float64
# ...

# %%
df.drop('ID_LAT_LON_YEAR_WEEK', 1, inplace=True)

# %%
df
# Out:
#        latitude  longitude  year  week_no  \
# 0        -0.510     29.290  2019        0
# 1        -0.510     29.290  2019        1
# 2        -0.510     29.290  2019        2
# 3        -0.510     29.290  2019        3
# 4        -0.510     29.290  2019        4
# ...         ...        ...   ...      ...
# 79018    -3.299     30.301  2021       48
# 79019    -3.299     30.301  2021       49
# 79020    -3.299     30.301  2021       50
# 79021    -3.299     30.301  2021       51
# 79022    -3.299     30.301  2021       52
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                     -0.000108
# 1                                      0.000021
# 2                                      0.000514
# 3                                           NaN
# 4                                     -0.000079
# ...                                         ...
# 79018                                  0.000284
# 79019                                  0.000083
# ...

# %% [markdown]
# ### GroupBy Function
# Let's do something with groupby function.
# - Groupby by:
#
#       - year
#       - latitude
#       - longitude
#       - week no
#   Here, emission is plotted with respect to these colums to know what is the distribution of C02 emission across these columns.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing the relevant data

# Create a 3x2 grid of subplots
fig, axes = plt.subplots(3, 2, figsize=(12, 10))

# Plot maximum emission by year in the first subplot
df.groupby(df['year']).max()['emission'].plot(kind='bar', ax=axes[0, 0])
axes[0, 0].set_title('Max Emission by Year')

# Plot mean emission by year in the second subplot
df.groupby(df['year']).mean()['emission'].plot(kind='bar', ax=axes[0, 1])
axes[0, 1].set_title('Mean Emission by Year')

# Plot mean emission by latitude in the third subplot
df.groupby(df['latitude']).mean()['emission'].plot(kind='line', ax=axes[1, 0])
axes[1, 0].set_title('Mean Emission by Latitude')

# Plot mean emission by longitude in the fourth subplot
df.groupby(df['longitude']).mean()['emission'].plot(kind='line', ax=axes[1, 1])
axes[1, 1].set_title('Mean Emission by Longitude')

# Plot mean emission by week number in the fifth subplot
df.groupby(df['week_no']).mean()['emission'].plot(kind='line', ax=axes[2, 0])
axes[2, 0].set_title('Mean Emission by Week Number')

df.groupby(df['week_no']).max()['emission'].plot(kind='line', ax=axes[2, 1])
axes[2, 1].set_title('Max Emission by Week Number')
# Remove any empty subplots
fig.tight_layout()

# Show the plots
plt.show()

# %%
df.dropna(inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing the relevant data

# Create a 3x2 grid of subplots
fig, axes = plt.subplots(3, 2, figsize=(12, 10))

# Plot maximum emission by year in the first subplot
df.groupby(df['year']).max()['emission'].plot(kind='bar', ax=axes[0, 0])
axes[0, 0].set_title('Max Emission by Year')

# Plot mean emission by year in the second subplot
df.groupby(df['year']).mean()['emission'].plot(kind='bar', ax=axes[0, 1])
axes[0, 1].set_title('Mean Emission by Year')

# Plot mean emission by latitude in the third subplot
df.groupby(df['latitude']).mean()['emission'].plot(kind='line', ax=axes[1, 0])
axes[1, 0].set_title('Mean Emission by Latitude')

# Plot mean emission by longitude in the fourth subplot
df.groupby(df['longitude']).mean()['emission'].plot(kind='line', ax=axes[1, 1])
axes[1, 1].set_title('Mean Emission by Longitude')

# Plot mean emission by week number in the fifth subplot
df.groupby(df['week_no']).mean()['emission'].plot(kind='line', ax=axes[2, 0])
axes[2, 0].set_title('Mean Emission by Week Number')

df.groupby(df['week_no']).max()['emission'].plot(kind='line', ax=axes[2, 1])
axes[2, 1].set_title('Max Emission by Week Number')
# Remove any empty subplots
fig.tight_layout()

# Show the plots
plt.show()

# %%
df.columns
# Out:
# Index(['latitude', 'longitude', 'year', 'week_no',
#        'SulphurDioxide_SO2_column_number_density',
#        'SulphurDioxide_SO2_column_number_density_amf',
#        'SulphurDioxide_SO2_slant_column_number_density',
#        'SulphurDioxide_cloud_fraction', 'SulphurDioxide_sensor_azimuth_angle',
#        'SulphurDioxide_sensor_zenith_angle',
#        'SulphurDioxide_solar_azimuth_angle',
#        'SulphurDioxide_solar_zenith_angle',
#        'SulphurDioxide_SO2_column_number_density_15km',
#        'CarbonMonoxide_CO_column_number_density',
#        'CarbonMonoxide_H2O_column_number_density',
#        'CarbonMonoxide_cloud_height', 'CarbonMonoxide_sensor_altitude',
#        'CarbonMonoxide_sensor_azimuth_angle',
#        'CarbonMonoxide_sensor_zenith_angle',
#        'CarbonMonoxide_solar_azimuth_angle',
#        'CarbonMonoxide_solar_zenith_angle',
#        'NitrogenDioxide_NO2_column_number_density',
#        'NitrogenDioxide_tropospheric_NO2_column_number_density',
# ...

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df' with the variables as columns

# Select the columns you want to analyze
columns_for_correlation = [
    'NitrogenDioxide_NO2_column_number_density',
    'NitrogenDioxide_tropospheric_NO2_column_number_density',
    'NitrogenDioxide_stratospheric_NO2_column_number_density',
    'NitrogenDioxide_NO2_slant_column_number_density',
    'NitrogenDioxide_tropopause_pressure',
    'NitrogenDioxide_absorbing_aerosol_index',
    'NitrogenDioxide_cloud_fraction',
    'NitrogenDioxide_sensor_altitude',
    'NitrogenDioxide_sensor_azimuth_angle',
    'NitrogenDioxide_sensor_zenith_angle',
    'NitrogenDioxide_solar_azimuth_angle',
    'NitrogenDioxide_solar_zenith_angle'
]

# Calculate the correlation matrix
correlation_matrix = df[columns_for_correlation].corr()

# Display the correlation matrix
correlation_matrix
# Out:
#                                                     NitrogenDioxide_NO2_column_number_density  \
# NitrogenDioxide_NO2_column_number_density                                            1.000000
# NitrogenDioxide_tropospheric_NO2_column_number_...                                   0.871304
# NitrogenDioxide_stratospheric_NO2_column_number...                                   0.522741
# NitrogenDioxide_NO2_slant_column_number_density                                      0.759612
# NitrogenDioxide_tropopause_pressure                                                  0.293004
# NitrogenDioxide_absorbing_aerosol_index                                              0.370465
# NitrogenDioxide_cloud_fraction                                                      -0.101420
# NitrogenDioxide_sensor_altitude                                                      0.028193
# NitrogenDioxide_sensor_azimuth_angle                                                -0.022029
# ...
